# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/drive/1HHBUSFAHD_IvdeTAF60p6mtmeabo1s9P?usp=sharing">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🕷️ Extract Houses Listing on Zillow with Official Scrapegraph SDK

# %% [markdown]
# ![banner-zillow-forsale.png](data:image/png;base64,...)

# %% [markdown]
# ### 🔧 Install `dependencies`

# %%
# %%capture
# !pip install scrapegraph-py

# %% [markdown]
# ### 🔑 Import `ScrapeGraph` API key

# %% [markdown]
# You can find the Scrapegraph API key [here](https://dashboard.scrapegraphai.com/)

# %%
import os
from getpass import getpass

# Check if the API key is already set in the environment
sgai_api_key = os.getenv("SGAI_API_KEY")

if sgai_api_key:
    print("SGAI_API_KEY found in environment.")
else:
    print("SGAI_API_KEY not found in environment.")
    # Prompt the user to input the API key securely (hidden input)
    sgai_api_key = getpass("Please enter your SGAI_API_KEY: ").strip()
    if sgai_api_key:
        # Set the API key in the environment
        os.environ["SGAI_API_KEY"] = sgai_api_key
        print("SGAI_API_KEY has been set in the environment.")
    else:
        print("No API key entered. Please set the API key to continue.")
# Out:
# SGAI_API_KEY not found in environment.
# Please enter your SGAI_API_KEY: ··········
# SGAI_API_KEY has been set in the environment.

# %% [markdown]
# ### 📝 Defining an `Output Schema` for Webpage Content Extraction

# %% [markdown]
# If you already know what you want to extract from a webpage, you can **define an output schema** using **Pydantic**. This schema acts as a "blueprint" that tells the AI how to structure the response.
#
# <details>
#   <summary>Pydantic Schema Quick Guide</summary>
#
# Types of Schemas
#
# 1. Simple Schema
# Use this when you want to extract straightforward information, such as a single piece of content.
#
# ```python
# from pydantic import BaseModel, Field
#
# # Simple schema for a single webpage
# class PageInfoSchema(BaseModel):
#     title: str = Field(description="The title of the webpage")
#     description: str = Field(description="The description of the webpage")
#
# # Example Output JSON after AI extraction
# {
#     "title": "ScrapeGraphAI: The Best Content Extraction Tool",
#     "description": "ScrapeGraphAI provides powerful tools for structured content extraction from websites."
# }
# ```
#
# 2. Complex Schema (Nested)
# If you need to extract structured information with multiple related items (like a list of repositories), you can **nest schemas**.
#
# ```python
# from pydantic import BaseModel, Field
# from typing import List
#
# # Define a schema for a single repository
# class RepositorySchema(BaseModel):
#     name: str = Field(description="Name of the repository (e.g., 'owner/repo')")
#     description: str = Field(description="Description of the repository")
#     stars: int = Field(description="Star count of the repository")
#     forks: int = Field(description="Fork count of the repository")
#     today_stars: int = Field(description="Stars gained today")
#     language: str = Field(description="Programming language used")
#
# # Define a schema for a list of repositories
# class ListRepositoriesSchema(BaseModel):
#     repositories: List[RepositorySchema] = Field(description="List of GitHub trending repositories")
#
# # Example Output JSON after AI extraction
# {
#     "repositories": [
#         {
#             "name": "google-gemini/cookbook",
#             "description": "Examples and guides for using the Gemini API",
#             "stars": 8036,
#             "forks": 1001,
#             "today_stars": 649,
#             "language": "Jupyter Notebook"
#         },
#         {
#             "name": "TEN-framework/TEN-Agent",
#             "description": "TEN Agent is a conversational AI powered by TEN, integrating Gemini 2.0 Multimodal Live API, OpenAI Realtime API, RTC, and more.",
#             "stars": 3224,
#             "forks": 311,
#             "today_stars": 361,
#             "language": "Python"
#         }
#     ]
# }
# ```
#
# Key Takeaways
# - **Simple Schema**: Perfect for small, straightforward extractions.
# - **Complex Schema**: Use nesting to extract lists or structured data, like "a list of repositories."
#
# Both approaches give the AI a clear structure to follow, ensuring that the extracted content matches exactly what you need.
# </details>

# %%
from pydantic import BaseModel, Field
from typing import List, Optional

# Schema for a single house listing
class HouseListingSchema(BaseModel):
    price: int = Field(description="Price of the house in USD")
    bedrooms: int = Field(description="Number of bedrooms")
    bathrooms: int = Field(description="Number of bathrooms")
    square_feet: int = Field(description="Total square footage of the house")
    address: str = Field(description="Address of the house")
    city: str = Field(description="City where the house is located")
    state: str = Field(description="State where the house is located")
    zip_code: str = Field(description="ZIP code of the house location")
    tags: List[str] = Field(description="Tags like 'New construction' or 'Large garage'")
    agent_name: str = Field(description="Name of the listing agent")
    agency: str = Field(description="Agency listing the house")

# Schema containing a list of house listings
class ZillowHouseListingsSchema(BaseModel):
    houses: List[HouseListingSchema] = Field(description="List of house listings on Zillow or similar platforms")

# %% [markdown]
# ### 🚀 Initialize `SGAI Client` and start extraction

# %% [markdown]
# Initialize the client for scraping (there's also an async version [here](https://github.com/ScrapeGraphAI/scrapegraph-sdk/blob/main/scrapegraph-py/examples/async_smartscraper_example.py))

# %%
from scrapegraph_py import Client

# Initialize the client with explicit API key
sgai_client = Client(api_key=sgai_api_key, timeout=240)

# %% [markdown]
# Here we use `Smartscraper` service to extract structured data using AI from a webpage.
#
#
# > If you already have an HTML file, you can upload it and use `Localscraper` instead.

# %%
# Request for Trending Repositories
repo_response = sgai_client.smartscraper(
    website_url="https://www.zillow.com/san-francisco-ca",
    user_prompt="Extract info about the houses visible on the page",
    output_schema=ZillowHouseListingsSchema,
)

# %% [markdown]
# Print the response

# %%
import json

# Print the response
request_id = repo_response['request_id']
result = repo_response['result']

print(f"Request ID: {request_id}")
print("Trending Repositories:")
print(json.dumps(result, indent=2))
# Out:
# Request ID: 6faba811-768f-431d-8581-c8c7a9be6e1f
# Trending Repositories:
# {
#   "houses": [
#     {
#       "price": 449000,
#       "bedrooms": 3,
#       "bathrooms": 3,
#       "square_feet": 2166,
#       "address": "3229 Jennings St",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94124",
#       "tags": [
#         "Large garage"
#       ],
#       "agent_name": "Michelle K. Pender",
#       "agency": "ENGEL & VOELKERS SAN FRANCISCO"
#     },
#     {
#       "price": 998800,
#       "bedrooms": 3,
#       "bathrooms": 3,
#       "square_feet": 1522,
#       "address": "71 Kirkwood Ave",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94124",
#       "tags": [
#         "New construction"
#       ],
#       "agent_name": "Lynn Anne Bell",
#       "agency": "CHRISTIE'S INT'L R.E. SF"
#     },
#     {
#       "price": 1098000,
#       "bedrooms": 2,
#       "bathrooms": 3,
#       "square_feet": 1460,
#       "address": "1370 41st Ave",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94122",
#       "tags": [
#         "Spacious primary suite"
#       ],
#       "agent_name": "Andrew de Vries",
#       "agency": "BERKSHIRE HATHAWAY-FRANCISCAN"
#     },
#     {
#       "price": 1900000,
#       "bedrooms": 3,
#       "bathrooms": 3,
#       "square_feet": 1670,
#       "address": "1011 Castro St",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94114",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 799000,
#       "bedrooms": 3,
#       "bathrooms": 2,
#       "square_feet": 1380,
#       "address": "1470 Palou Ave",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94124",
#       "tags": [],
#       "agent_name": "Vincent Heung",
#       "agency": "COMPASS"
#     },
#     {
#       "price": 20000000,
#       "bedrooms": 6,
#       "bathrooms": 8,
#       "square_feet": 10961,
#       "address": "540 El Camino Del Mar",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94121",
#       "tags": [
#         "Corner parcel"
#       ],
#       "agent_name": "Steven Mavromihalis",
#       "agency": "COMPASS"
#     },
#     {
#       "price": 995000,
#       "bedrooms": 1,
#       "bathrooms": 2,
#       "square_feet": 1690,
#       "address": "426 3rd Ave",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94118",
#       "tags": [],
#       "agent_name": "Rachel E. Swann",
#       "agency": "COLDWELL BANKER REALTY"
#     },
#     {
#       "price": 207555,
#       "bedrooms": 1,
#       "bathrooms": 1,
#       "square_feet": 1593,
#       "address": "2040 Fell St APT 10",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94117",
#       "tags": [],
#       "agent_name": "Trista Elizabeth Bernasconi",
#       "agency": "COMPASS"
#     },
#     {
#       "price": 795000,
#       "bedrooms": 4,
#       "bathrooms": 2,
#       "square_feet": 1417,
#       "address": "515 Athens St",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94112",
#       "tags": [
#         "Level fenced rear yard"
#       ],
#       "agent_name": "Darin J. Holwitz",
#       "agency": "COMPASS"
#     },
#     {
#       "price": 989166,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Western Addition",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94115",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 1112076,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Mission Dolores",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94110",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 1811366,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Dolores Heights",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94114",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 665583,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Civic Center",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94102",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 1682313,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Eureka Valley",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94117",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 1604011,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Buena Vista",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94118",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 1291908,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Panhandle",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94107",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 676652,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Cathedral Hill",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94123",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 1188108,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Lower Haight",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94109",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 1009604,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Hayes Valley",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94103",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 1302271,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Haight",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94114",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 1302918,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Duboce Triangle",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94110",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 939058,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Japantown",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94108",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 1123100,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Alamo Square",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94115",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 2002541,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Ashbury Heights",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94117",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 1418113,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Castro",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94114",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 1455036,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Corona Heights",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94114",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 962151,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Mint Hill",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94110",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 1162299,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Anza Vista",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94118",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     },
#     {
#       "price": 1626428,
#       "bedrooms": 0,
#       "bathrooms": 0,
#       "square_feet": 0,
#       "address": "Cole Valley",
#       "city": "San Francisco",
#       "state": "CA",
#       "zip_code": "94114",
#       "tags": [],
#       "agent_name": "NA",
#       "agency": "NA"
#     }
#   ]
# }

# %% [markdown]
# ### 💾 Save the output to a `CSV` file

# %% [markdown]
# Let's create a pandas dataframe and show the table with the extracted content

# %%
import pandas as pd

# Convert dictionary to DataFrame
df = pd.DataFrame(result["houses"])
df
# Out:
#        price  bedrooms  bathrooms  square_feet                address  \
# 0     449000         3          3         2166       3229 Jennings St
# 1     998800         3          3         1522        71 Kirkwood Ave
# 2    1098000         2          3         1460          1370 41st Ave
# 3    1900000         3          3         1670         1011 Castro St
# 4     799000         3          2         1380         1470 Palou Ave
# 5   20000000         6          8        10961  540 El Camino Del Mar
# 6     995000         1          2         1690            426 3rd Ave
# 7     207555         1          1         1593    2040 Fell St APT 10
# 8     795000         4          2         1417          515 Athens St
# 9     989166         0          0            0       Western Addition
# 10   1112076         0          0            0        Mission Dolores
# 11   1811366         0          0            0        Dolores Heights
# 12    665583         0          0            0           Civic Center
# 13   1682313         0          0            0          Eureka Valley
# 14   1604011         0          0            0            Buena Vista
# 15   1291908         0          0            0              Panhandle
# 16    676652         0          0            0         Cathedral Hill
# 17   1188108         0          0            0           Lower Haight
# 18   1009604         0          0            0           Hayes Valley
# 19   1302271         0          0            0                 Haight
# 20   1302918         0          0            0        Duboce Triangle
# 21    939058         0          0            0              Japantown
# 22   1123100         0          0            0           Alamo Square
# 23   2002541         0          0            0        Ashbury Heights
# 24   1418113         0          0            0                 Castro
# 25   1455036         0          0            0         Corona Heights
# 26    962151         0          0            0              Mint Hill
# 27   1162299         0          0            0             Anza Vista
# 28   1626428         0          0            0            Cole Valley
#
#              city state zip_code                      tags  \
# 0   San Francisco    CA    94124            [Large garage]
# 1   San Francisco    CA    94124        [New construction]
# 2   San Francisco    CA    94122  [Spacious primary suite]
# 3   San Francisco    CA    94114                        []
# 4   San Francisco    CA    94124                        []
# 5   San Francisco    CA    94121           [Corner parcel]
# 6   San Francisco    CA    94118                        []
# 7   San Francisco    CA    94117                        []
# 8   San Francisco    CA    94112  [Level fenced rear yard]
# 9   San Francisco    CA    94115                        []
# 10  San Francisco    CA    94110                        []
# 11  San Francisco    CA    94114                        []
# 12  San Francisco    CA    94102                        []
# 13  San Francisco    CA    94117                        []
# 14  San Francisco    CA    94118                        []
# 15  San Francisco    CA    94107                        []
# 16  San Francisco    CA    94123                        []
# 17  San Francisco    CA    94109                        []
# 18  San Francisco    CA    94103                        []
# 19  San Francisco    CA    94114                        []
# 20  San Francisco    CA    94110                        []
# 21  San Francisco    CA    94108                        []
# 22  San Francisco    CA    94115                        []
# 23  San Francisco    CA    94117                        []
# 24  San Francisco    CA    94114                        []
# 25  San Francisco    CA    94114                        []
# 26  San Francisco    CA    94110                        []
# 27  San Francisco    CA    94118                        []
# 28  San Francisco    CA    94114                        []
#
#                      agent_name                          agency
# 0            Michelle K. Pender  ENGEL & VOELKERS SAN FRANCISCO
# 1                Lynn Anne Bell        CHRISTIE'S INT'L R.E. SF
# 2               Andrew de Vries   BERKSHIRE HATHAWAY-FRANCISCAN
# 3                            NA                              NA
# 4                 Vincent Heung                         COMPASS
# 5           Steven Mavromihalis                         COMPASS
# 6               Rachel E. Swann          COLDWELL BANKER REALTY
# 7   Trista Elizabeth Bernasconi                         COMPASS
# 8              Darin J. Holwitz                         COMPASS
# 9                            NA                              NA
# 10                           NA                              NA
# 11                           NA                              NA
# 12                           NA                              NA
# 13                           NA                              NA
# 14                           NA                              NA
# 15                           NA                              NA
# 16                           NA                              NA
# 17                           NA                              NA
# 18                           NA                              NA
# 19                           NA                              NA
# 20                           NA                              NA
# 21                           NA                              NA
# 22                           NA                              NA
# 23                           NA                              NA
# 24                           NA                              NA
# 25                           NA                              NA
# 26                           NA                              NA
# 27                           NA                              NA
# 28                           NA                              NA

# %% [markdown]
# Save it to CSV

# %%
# Save the DataFrame to a CSV file
csv_file = "zillow_forsale.csv"
df.to_csv(csv_file, index=False)
print(f"Data saved to {csv_file}")
# Out:
# Data saved to zillow_forsale.csv

# %% [markdown]
# ## 🔗 Resources

# %% [markdown]
# <p align="left">
#   <img src="https://raw.githubusercontent.com/VinciGit00/Scrapegraph-ai/main/docs/assets/api-banner.png"
#        alt="ScrapeGraph API Banner" width="600">
# </p>
#
#
# - 🚀 **Get your API Key:** [ScrapeGraphAI Dashboard](https://dashboard.scrapegraphai.com)
# - 🐙 **GitHub:** [ScrapeGraphAI GitHub](https://github.com/scrapegraphai)
# - 💼 **LinkedIn:** [ScrapeGraphAI LinkedIn](https://www.linkedin.com/company/scrapegraphai/)
# - 🐦 **Twitter:** [ScrapeGraphAI Twitter](https://twitter.com/scrapegraphai)
# - 💬 **Discord:** [Join our Discord Community](https://discord.gg/uJN7TYcpNa)
#
# Made with ❤️ by the [ScrapeGraphAI](https://scrapegraphai.com) Team
